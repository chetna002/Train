# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import datasets

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\uzuma\Downloads\train.csv")

# %%
df
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0      Scientist      19114.12            1824.843333                  3  ...
# 1      Scientist      19114.12                    NaN                  3  ...
# 2      Scientist      19114.12                    NaN                  3  ...
# 3      Scientist      19114.12                    NaN                  3  ...
# 4      Scientist      19114.12            1824.843333                  3  ...
# ...          ...           ...                    ...                ...  ...
# 99995   Mechanic      39628.99            3359.415833                  4  ...
# 99996   Mechanic      39628.99            3359.415833                  4  ...
# 99997   Mechanic      39628.99            3359.415833                  4  ...
# 99998   Mechanic      39628.99            3359.415833                  4  ...
# 99999   Mechanic     39628.99_            3359.415833                  4  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# 0               _            809.98                26.822620
# 1            Good            809.98                31.944960
# 2            Good            809.98                28.609352
# 3            Good            809.98                31.377862
# 4            Good            809.98                24.797347
# ...           ...               ...                      ...
# 99995           _            502.38                34.663572
# 99996           _            502.38                40.565631
# 99997        Good            502.38                41.255522
# 99998        Good            502.38                33.638208
# 99999        Good            502.38                34.192463
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
# 0       22 Years and 1 Months                     No           49.574949
# 1                         NaN                     No           49.574949
# 2       22 Years and 3 Months                     No           49.574949
# 3       22 Years and 4 Months                     No           49.574949
# 4       22 Years and 5 Months                     No           49.574949
# ...                       ...                    ...                 ...
# 99995   31 Years and 6 Months                     No           35.104023
# 99996   31 Years and 7 Months                     No           35.104023
# 99997   31 Years and 8 Months                     No           35.104023
# 99998   31 Years and 9 Months                     No           35.104023
# 99999  31 Years and 10 Months                     No           35.104023
#
#       Amount_invested_monthly                 Payment_Behaviour  \
# 0           80.41529543900253   High_spent_Small_value_payments
# 1          118.28022162236736    Low_spent_Large_value_payments
# 2             81.699521264648   Low_spent_Medium_value_payments
# 3           199.4580743910713    Low_spent_Small_value_payments
# 4          41.420153086217326  High_spent_Medium_value_payments
# ...                       ...                               ...
# 99995       60.97133255718485   High_spent_Large_value_payments
# 99996       54.18595028760385  High_spent_Medium_value_payments
# 99997       24.02847744864441   High_spent_Large_value_payments
# 99998      251.67258219721603    Low_spent_Large_value_payments
# 99999       167.1638651610451                            !@9#%8
#
#           Monthly_Balance Credit_Score
# 0      312.49408867943663         Good
# 1      284.62916249607184         Good
# 2       331.2098628537912         Good
# 3      223.45130972736786         Good
# 4      341.48923103222177         Good
# ...                   ...          ...
# 99995          479.866228         Poor
# 99996           496.65161         Poor
# 99997          516.809083         Poor
# 99998          319.164979     Standard
# 99999          393.673696         Poor
#
# [100000 rows x 28 columns]

# %%
df.shape
# Out:
# (100000, 28)

# %%
df.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           84998.000000      100000.000000     100000.00000
# mean             4194.170850          17.091280         22.47443
# std              3183.686167         117.404834        129.05741
# min               303.645417          -1.000000          0.00000
# 25%              1625.568229           3.000000          4.00000
# 50%              3093.745000           6.000000          5.00000
# 75%              5957.448333           7.000000          7.00000
# max             15204.633333        1798.000000       1499.00000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count  100000.000000        100000.000000          98035.000000
# mean       72.466040            21.068780             27.754251
# std       466.422621            14.860104            193.177339
# min         1.000000            -5.000000              0.000000
# 25%         8.000000            10.000000              3.000000
# 50%        13.000000            18.000000              6.000000
# 75%        20.000000            28.000000              9.000000
# max      5797.000000            67.000000           2597.000000
#
#        Credit_Utilization_Ratio  Total_EMI_per_month
# count             100000.000000        100000.000000
# mean                  32.285173          1403.118217
# std                    5.116875          8306.041270
# min                   20.000000             0.000000
# 25%                   28.052567            30.306660
# 50%                   32.305784            69.249473
# 75%                   36.496663           161.224249
# max                   50.000000         82331.000000

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# ID                           0.000
# Customer_ID                  0.000
# Month                        0.000
# Name                         9.985
# Age                          0.000
# SSN                          0.000
# Occupation                   0.000
# Annual_Income                0.000
# Monthly_Inhand_Salary       15.002
# Num_Bank_Accounts            0.000
# Num_Credit_Card              0.000
# Interest_Rate                0.000
# Num_of_Loan                  0.000
# Type_of_Loan                11.408
# Delay_from_due_date          0.000
# Num_of_Delayed_Payment       7.002
# Changed_Credit_Limit         0.000
# Num_Credit_Inquiries         1.965
# Credit_Mix                   0.000
# Outstanding_Debt             0.000
# Credit_Utilization_Ratio     0.000
# Credit_History_Age           9.030
# Payment_of_Min_Amount        0.000
# Total_EMI_per_month          0.000
# Amount_invested_monthly      4.479
# Payment_Behaviour            0.000
# Monthly_Balance              1.200
# Credit_Score                 0.000
# dtype: float64

# %%
df.isna().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# dtype: object

# %%
df.select_dtypes(include="O").columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Num_of_Loan', 'Type_of_Loan',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_History_Age', 'Payment_of_Min_Amount',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
ls=["ID","Customer_ID","Amount_invested_monthly","SSN","Name","Payment_Behaviour","Payment_of_Min_Amount","Type_of_Loan","Credit_History_Age"]

# %%
df.drop(ls,axis=1,inplace=True)

# %%
df
# Out:
#           Month   Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0       January    23  Scientist      19114.12            1824.843333
# 1      February    23  Scientist      19114.12                    NaN
# 2         March  -500  Scientist      19114.12                    NaN
# 3         April    23  Scientist      19114.12                    NaN
# 4           May    23  Scientist      19114.12            1824.843333
# ...         ...   ...        ...           ...                    ...
# 99995     April    25   Mechanic      39628.99            3359.415833
# 99996       May    25   Mechanic      39628.99            3359.415833
# 99997      June    25   Mechanic      39628.99            3359.415833
# 99998      July    25   Mechanic      39628.99            3359.415833
# 99999    August    25   Mechanic     39628.99_            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                      3                4              3           4
# 1                      3                4              3           4
# 2                      3                4              3           4
# 3                      3                4              3           4
# 4                      3                4              3           4
# ...                  ...              ...            ...         ...
# 99995                  4                6              7           2
# 99996                  4                6              7           2
# 99997                  4                6           5729           2
# 99998                  4                6              7           2
# 99999                  4                6              7           2
#
#        Delay_from_due_date Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                        3                      7                11.27
# 1                       -1                    NaN                11.27
# 2                        3                      7                    _
# 3                        5                      4                 6.27
# 4                        6                    NaN                11.27
# ...                    ...                    ...                  ...
# 99995                   23                      7                 11.5
# 99996                   18                      7                 11.5
# 99997                   27                      6                 11.5
# 99998                   20                    NaN                 11.5
# 99999                   18                      6                 11.5
#
#        Num_Credit_Inquiries Credit_Mix Outstanding_Debt  \
# 0                       4.0          _           809.98
# 1                       4.0       Good           809.98
# 2                       4.0       Good           809.98
# 3                       4.0       Good           809.98
# 4                       4.0       Good           809.98
# ...                     ...        ...              ...
# 99995                   3.0          _           502.38
# 99996                   3.0          _           502.38
# 99997                   3.0       Good           502.38
# 99998                   3.0       Good           502.38
# 99999                   3.0       Good           502.38
#
#        Credit_Utilization_Ratio  Total_EMI_per_month     Monthly_Balance  \
# 0                     26.822620            49.574949  312.49408867943663
# 1                     31.944960            49.574949  284.62916249607184
# 2                     28.609352            49.574949   331.2098628537912
# 3                     31.377862            49.574949  223.45130972736786
# 4                     24.797347            49.574949  341.48923103222177
# ...                         ...                  ...                 ...
# 99995                 34.663572            35.104023          479.866228
# 99996                 40.565631            35.104023           496.65161
# 99997                 41.255522            35.104023          516.809083
# 99998                 33.638208            35.104023          319.164979
# 99999                 34.192463            35.104023          393.673696
#
#       Credit_Score
# 0             Good
# 1             Good
# 2             Good
# 3             Good
# 4             Good
# ...            ...
# 99995         Poor
# 99996         Poor
# 99997         Poor
# 99998     Standard
# 99999         Poor
#
# [100000 rows x 19 columns]

# %%
df.select_dtypes(include="O").columns
# Out:
# Index(['Month', 'Age', 'Occupation', 'Annual_Income', 'Num_of_Loan',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Credit_Mix',
#        'Outstanding_Debt', 'Monthly_Balance', 'Credit_Score'],
#       dtype='object')

# %%
ls=['Month', 'Age', 'Occupation', 'Annual_Income', 'Num_of_Loan',
       'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Credit_Mix',
       'Outstanding_Debt', 'Monthly_Balance', 'Credit_Score']

# %%
cols=ls

# %%
for i in cols:
    print(f"{i}")
df=df.dropna(subset=cols)
# Out:
# Month
# Age
# Occupation
# Annual_Income
# Num_of_Loan
# Num_of_Delayed_Payment
# Changed_Credit_Limit
# Credit_Mix
# Outstanding_Debt
# Monthly_Balance
# Credit_Score

# %%
df
# Out:
#          Month   Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0      January    23  Scientist      19114.12            1824.843333
# 2        March  -500  Scientist      19114.12                    NaN
# 3        April    23  Scientist      19114.12                    NaN
# 5         June    23  Scientist      19114.12                    NaN
# 6         July    23  Scientist      19114.12            1824.843333
# ...        ...   ...        ...           ...                    ...
# 99994    March    25   Mechanic      39628.99            3359.415833
# 99995    April    25   Mechanic      39628.99            3359.415833
# 99996      May    25   Mechanic      39628.99            3359.415833
# 99997     June    25   Mechanic      39628.99            3359.415833
# 99999   August    25   Mechanic     39628.99_            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                      3                4              3           4
# 2                      3                4              3           4
# 3                      3                4              3           4
# 5                      3                4              3           4
# 6                      3                4              3           4
# ...                  ...              ...            ...         ...
# 99994                  4                6              7           2
# 99995                  4                6              7           2
# 99996                  4                6              7           2
# 99997                  4                6           5729           2
# 99999                  4                6              7           2
#
#        Delay_from_due_date Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                        3                      7                11.27
# 2                        3                      7                    _
# 3                        5                      4                 6.27
# 5                        8                      4                 9.27
# 6                        3                     8_                11.27
# ...                    ...                    ...                  ...
# 99994                   20                      6                  9.5
# 99995                   23                      7                 11.5
# 99996                   18                      7                 11.5
# 99997                   27                      6                 11.5
# 99999                   18                      6                 11.5
#
#        Num_Credit_Inquiries Credit_Mix Outstanding_Debt  \
# 0                       4.0          _           809.98
# 2                       4.0       Good           809.98
# 3                       4.0       Good           809.98
# 5                       4.0       Good           809.98
# 6                       4.0       Good           809.98
# ...                     ...        ...              ...
# 99994                   3.0          _           502.38
# 99995                   3.0          _           502.38
# 99996                   3.0          _           502.38
# 99997                   3.0       Good           502.38
# 99999                   3.0       Good           502.38
#
#        Credit_Utilization_Ratio  Total_EMI_per_month     Monthly_Balance  \
# 0                     26.822620            49.574949  312.49408867943663
# 2                     28.609352            49.574949   331.2098628537912
# 3                     31.377862            49.574949  223.45130972736786
# 5                     27.262259            49.574949   340.4792117872438
# 6                     22.537593            49.574949   244.5653167062043
# ...                         ...                  ...                 ...
# 99994                 39.323569            35.104023          410.256158
# 99995                 34.663572            35.104023          479.866228
# 99996                 40.565631            35.104023           496.65161
# 99997                 41.255522            35.104023          516.809083
# 99999                 34.192463            35.104023          393.673696
#
#       Credit_Score
# 0             Good
# 2             Good
# 3             Good
# 5             Good
# 6             Good
# ...            ...
# 99994         Poor
# 99995         Poor
# 99996         Poor
# 99997         Poor
# 99999         Poor
#
# [91893 rows x 19 columns]

# %%
df.isna().sum()
# Out:
# Month                           0
# Age                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       13806
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Delay_from_due_date             0
# Num_of_Delayed_Payment          0
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1809
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Total_EMI_per_month             0
# Monthly_Balance                 0
# Credit_Score                    0
# dtype: int64

# %%
df["Age"]
# Out:
# 0          23
# 2        -500
# 3          23
# 5          23
# 6          23
#          ...
# 99994      25
# 99995      25
# 99996      25
# 99997      25
# 99999      25
# Name: Age, Length: 91893, dtype: object

# %%
ls=[]
for i in df["Age"]:
    text=str(i).split("_")[0]
    ls.append(text)

# %%
df["Age"]=ls

# %%
df["Age"]=df["Age"].astype("int")

# %%
df["Age"].mean()
# Out:
# np.float64(111.29435321515241)

# %%
mini=df["Age"].min()
Q1=df["Age"].quantile(0.25)
Q2=df["Age"].quantile(0.50)
Q3=df["Age"].quantile(0.75)
Max=df["Age"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 69.0
# Lower- -3.0

# %%
df[df["Age"]<Lower_fence]
# Out:
#           Month  Age    Occupation Annual_Income  Monthly_Inhand_Salary  \
# 2         March -500     Scientist      19114.12                    NaN
# 113    February -500  Entrepreneur      25546.26                    NaN
# 289    February -500      Mechanic      29469.98            2227.831667
# 340         May -500     Architect      20574.47            1740.539167
# 560     January -500     Scientist     144546.72           11809.560000
# ...         ...  ...           ...           ...                    ...
# 99129  February -500        Lawyer      77633.04            6635.420000
# 99531     April -500        Lawyer      8974.555                    NaN
# 99541      June -500     Scientist      34671.15            2637.262500
# 99762     March -500    Accountant       17818.6            1659.883333
# 99963     April -500        Lawyer      42903.79                    NaN
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 2                      3                4              3           4
# 113                    8                7             14           5
# 289                    7                7             24           5
# 340                    6             1327             14           4
# 560                    0                3              7           2
# ...                  ...              ...            ...         ...
# 99129                  7                5             34           5
# 99531                 10                8             28           7
# 99541                  4                3             16           2
# 99762                  4                6             14           1
# 99963                  0                4              6           1
#
#        Delay_from_due_date Num_of_Delayed_Payment Changed_Credit_Limit  \
# 2                        3                      7                    _
# 113                     16                     13                 7.83
# 289                     50                     18                22.94
# 340                      6                      7                13.74
# 560                     15                      7                 6.08
# ...                    ...                    ...                  ...
# 99129                   55                     23                15.48
# 99531                   21                     24                 8.87
# 99541                   21                     19                11.27
# 99762                   25                    15_                10.91
# 99963                   14                      0                  5.1
#
#        Num_Credit_Inquiries Credit_Mix Outstanding_Debt  \
# 2                       4.0       Good           809.98
# 113                     NaN   Standard           758.44
# 289                     NaN        Bad          3421.66
# 340                    11.0   Standard           749.95
# 560                     1.0       Good          1045.11
# ...                     ...        ...              ...
# 99129                   8.0        Bad          3392.65
# 99531                   7.0        Bad          1660.14
# 99541                   4.0   Standard          1071.97
# 99762                   3.0   Standard           301.52
# 99963                   1.0       Good          1079.48
#
#        Credit_Utilization_Ratio  Total_EMI_per_month     Monthly_Balance  \
# 2                     28.609352            49.574949   331.2098628537912
# 113                   29.711376           101.328637   129.9336309554582
# 289                   30.268411            69.685459   287.6059398340756
# 340                   29.036164            49.348666  254.72668807344257
# 560                   40.840687           136.988557   730.5558529037837
# ...                         ...                  ...                 ...
# 99129                 39.115792           227.777065          585.930667
# 99531                 22.173985            30.443262          300.106469
# 99541                 25.076571            52.337589          366.605518
# 99762                 26.398987            11.581102          369.426905
# 99963                 30.625298            34.975457          520.662207
#
#       Credit_Score
# 2             Good
# 113       Standard
# 289       Standard
# 340       Standard
# 560       Standard
# ...            ...
# 99129     Standard
# 99531         Poor
# 99541     Standard
# 99762     Standard
# 99963     Standard
#
# [826 rows x 19 columns]

# %%
df.loc[df["Age"]<Lower_fence,"Age"]=0

# %%
df[df["Age"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df["Month"].dtypes
# Out:
# dtype('O')

# %%
df["Annual_Income"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Annual_Income"]
# Out:
# 0         19114.12
# 2         19114.12
# 3         19114.12
# 5         19114.12
# 6         19114.12
#            ...
# 99994     39628.99
# 99995     39628.99
# 99996     39628.99
# 99997     39628.99
# 99999    39628.99_
# Name: Annual_Income, Length: 91893, dtype: object

# %%
import  re

# %%
def removal(text):
    return re.sub("_","",text)

# %%
df["Annual_Income"]=df["Annual_Income"].apply(lambda x: removal(x))

# %%
df["Annual_Income"]=df["Annual_Income"].astype("float")

# %%
mini=df["Annual_Income"].min()
Q1=df["Annual_Income"].quantile(0.25)
Q2=df["Annual_Income"].quantile(0.50)
Q3=df["Annual_Income"].quantile(0.75)
Max=df["Annual_Income"].max()

IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 151274.22
# Lower- -59813.7

# %%
df[df["Annual_Income"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df["Monthly_Inhand_Salary"]
# Out:
# 0        1824.843333
# 2                NaN
# 3                NaN
# 5                NaN
# 6        1824.843333
#             ...
# 99994    3359.415833
# 99995    3359.415833
# 99996    3359.415833
# 99997    3359.415833
# 99999    3359.415833
# Name: Monthly_Inhand_Salary, Length: 91893, dtype: float64

# %%
mean= df["Monthly_Inhand_Salary"].fillna(df["Monthly_Inhand_Salary"].mean())
median= df["Monthly_Inhand_Salary"].fillna(df["Monthly_Inhand_Salary"].median())
std= df["Monthly_Inhand_Salary"].fillna(df["Monthly_Inhand_Salary"].std())
ffill= df["Monthly_Inhand_Salary"].ffill()
bfill= df["Monthly_Inhand_Salary"].bfill()
const= df["Monthly_Inhand_Salary"].fillna(0)

# %%
print("the mean is=",mean.mean())
print("the median is=",median.mean())
print("the std is=",std.mean())
print("the ffill is=",ffill.mean())
print("the bfill is=",bfill.mean())
print("the const is=",const.mean())
# Out:
# the mean is= 4154.559409814968
# the median is= 3989.897887208181
# the std is= 4006.048188906355
# the ffill is= 4158.008902577724
# the bfill is= 4158.622841484086
# the const is= 3530.3785993951806

# %%
print("The actual mean is "),df["Monthly_Inhand_Salary"].mean()
# Out:
# The actual mean is
# (None, np.float64(4154.559409814967))

# %%
ffill.std()
# Out:
# np.float64(3171.4796263980234)

# %%
bfill.std()
# Out:
# np.float64(3169.2710377383323)

# %%
mean.std()
# Out:
# np.float64(2918.553671126722)

# %%
df["Monthly_Inhand_Salary"]=df["Monthly_Inhand_Salary"].bfill()

# %%
mini=df["Monthly_Inhand_Salary"].min()
Q1=df["Monthly_Inhand_Salary"].quantile(0.25)
Q2=df["Monthly_Inhand_Salary"].quantile(0.50)
Q3=df["Monthly_Inhand_Salary"].quantile(0.75)
Max=df["Monthly_Inhand_Salary"].max()

IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 12341.563749999998
# Lower- -4813.6729166666655

# %%
df[df["Monthly_Inhand_Salary"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
def removal (num):
    return re.sub("_","",num)

# %%
df["Num_of_Loan"]=df["Num_of_Loan"].apply(lambda x: removal(x))

# %%
df["Num_of_Loan"]=df["Num_of_Loan"].astype("int")

# %%
df[df["Num_of_Loan"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df.loc[df["Num_of_Loan"]<Lower_fence,"Num_of_Loan"]=0

# %%
df[df["Num_of_Loan"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df["Delay_from_due_date"].isna().sum()
# Out:
# np.int64(0)

# %%
mini=df["Delay_from_due_date"].min()
Q1=df["Delay_from_due_date"].quantile(0.25)
Q2=df["Delay_from_due_date"].quantile(0.50)
Q3=df["Delay_from_due_date"].quantile(0.75)
Max=df["Delay_from_due_date"].max()

IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 55.0
# Lower- -17.0

# %%
df[df["Delay_from_due_date"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df["Num_of_Delayed_Payment"].dtype
# Out:
# dtype('O')

# %%
df["Changed_Credit_Limit"]
# Out:
# 0        11.27
# 2            _
# 3         6.27
# 5         9.27
# 6        11.27
#          ...
# 99994      9.5
# 99995     11.5
# 99996     11.5
# 99997     11.5
# 99999     11.5
# Name: Changed_Credit_Limit, Length: 91893, dtype: object

# %%
df["Changed_Credit_Limit"]=df["Changed_Credit_Limit"].replace("_",np.nan)

# %%
df["Num_Credit_Inquiries"].isna().sum()
# Out:
# np.int64(1809)

# %%
df["Num_Credit_Inquiries"].ffill()
# Out:
# 0        4.0
# 2        4.0
# 3        4.0
# 5        4.0
# 6        4.0
#         ...
# 99994    3.0
# 99995    3.0
# 99996    3.0
# 99997    3.0
# 99999    3.0
# Name: Num_Credit_Inquiries, Length: 91893, dtype: float64

# %%
df["Num_Credit_Inquiries"].isna().sum()
# Out:
# np.int64(1809)

# %%
mini=df["Num_Credit_Inquiries"].min()
Q1=df["Num_Credit_Inquiries"].quantile(0.25)
Q2=df["Num_Credit_Inquiries"].quantile(0.50)
Q3=df["Num_Credit_Inquiries"].quantile(0.75)
Max=df["Num_Credit_Inquiries"].max()

IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 18.0
# Lower- -6.0

# %%
df[df["Num_Credit_Inquiries"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df["Credit_Mix"]
# Out:
# 0           _
# 2        Good
# 3        Good
# 5        Good
# 6        Good
#          ...
# 99994       _
# 99995       _
# 99996       _
# 99997    Good
# 99999    Good
# Name: Credit_Mix, Length: 91893, dtype: object

# %%
def removal (credit): 
    return re.sub("_","Bad",credit)

# %%
df["Credit_Mix"]=df["Credit_Mix"].apply(lambda x: removal(x))

# %%
df["Credit_Mix"]=df["Credit_Mix"]

# %%
df["Outstanding_Debt"]
# Out:
# 0        809.98
# 2        809.98
# 3        809.98
# 5        809.98
# 6        809.98
#           ...
# 99994    502.38
# 99995    502.38
# 99996    502.38
# 99997    502.38
# 99999    502.38
# Name: Outstanding_Debt, Length: 91893, dtype: object

# %%
def removal (num):
    return re.sub("_","",num)

# %%
df["Outstanding_Debt"]=df["Outstanding_Debt"].apply(lambda x: removal(x))

# %%
df["Outstanding_Debt"]=df["Outstanding_Debt"].astype("float")

# %%
df["Outstanding_Debt"].mean()
# Out:
# np.float64(1421.6847109137805)

# %%
mini=df["Outstanding_Debt"].min()
Q1=df["Outstanding_Debt"].quantile(0.25)
Q2=df["Outstanding_Debt"].quantile(0.50)
Q3=df["Outstanding_Debt"].quantile(0.75)
Max=df["Outstanding_Debt"].max()

IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 4003.3050000000003
# Lower- -1497.535

# %%
df[df["Outstanding_Debt"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df["Credit_Utilization_Ratio"]
# Out:
# 0        26.822620
# 2        28.609352
# 3        31.377862
# 5        27.262259
# 6        22.537593
#            ...
# 99994    39.323569
# 99995    34.663572
# 99996    40.565631
# 99997    41.255522
# 99999    34.192463
# Name: Credit_Utilization_Ratio, Length: 91893, dtype: float64

# %%
mini=df["Credit_Utilization_Ratio"].min()
Q1=df["Credit_Utilization_Ratio"].quantile(0.25)
Q2=df["Credit_Utilization_Ratio"].quantile(0.50)
Q3=df["Credit_Utilization_Ratio"].quantile(0.75)
Max=df["Credit_Utilization_Ratio"].max()

IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 49.18127088100376
# Lower- 15.442462977386263

# %%
df[df["Credit_Utilization_Ratio"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df["Monthly_Balance"].isna().sum()
# Out:
# np.int64(0)

# %%
ls = []
for i in df["Monthly_Balance"]:
    text = str(i).strip("__")
    number = text.split("_")[0]
    ls.append(number)

# %%
df["Monthly_Balance"]=ls

# %%
df["Monthly_Balance"]=df["Monthly_Balance"].astype('float')

# %%
df["Monthly_Balance"].mean()
# Out:
# np.float64(-3.2646665143155622e+22)

# %%
mini=df["Monthly_Balance"].min()
Q1=df["Monthly_Balance"].quantile(0.25)
Q2=df["Monthly_Balance"].quantile(0.50)
Q3=df["Monthly_Balance"].quantile(0.75)
Max=df["Monthly_Balance"].max()

IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 770.0502086148866
# Lower- -29.81116048708583

# %%
df[df["Monthly_Balance"]<Lower_fence]
# Out:
#           Month  Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 5545   February   17   Developer      41086.400            3660.866667
# 26177  February   45    Engineer      29728.310            2551.359167
# 29158      July   55      Lawyer      30748.930            2572.410833
# 35570     March   45     _______      20929.295            1704.107917
# 38622      July   21      Doctor      15167.620            1471.968333
# 60009  February   30  Journalist      92114.680            7811.223333
# 75251     April   29    Mechanic      60904.590            5080.382500
# 82918      July   44  Journalist      61990.520            4900.876667
# 83255    August   31      Doctor     126353.040           10635.420000
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 5545                   3                4              6            7
# 26177                  3                4              6            2
# 29158                  1                6             12            2
# 35570                  5                3              9            3
# 38622                  4                5              3            1
# 60009                  3                4              8            1
# 75251                  3                4             12            2
# 82918                 10               10             25            9
# 83255                  4                7             19            2
#
#        Delay_from_due_date Num_of_Delayed_Payment Changed_Credit_Limit  \
# 5545                    10                     17                17.86
# 26177                   15                      0                 7.81
# 29158                   10                      3                 4.21
# 35570                   14                      5                 1.99
# 38622                    4                      4                10.36
# 60009                   24                     10                17.87
# 75251                   22                     14                18.37
# 82918                   18                     23                19.32
# 83255                   10                     11                 9.43
#
#        Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 5545                   10.0   Standard            113.98
# 26177                   3.0       Good            917.00
# 29158                   9.0       Good            860.97
# 35570                   4.0        Bad            858.09
# 38622                   7.0       Good            847.03
# 60009                   7.0   Standard            820.52
# 75251                   8.0   Standard           2441.47
# 82918                   9.0        Bad           3618.91
# 83255                   3.0        Bad            859.77
#
#        Credit_Utilization_Ratio  Total_EMI_per_month  Monthly_Balance  \
# 5545                  34.826541           145.544320    -3.333333e+26
# 26177                 38.198076            34.496445    -3.333333e+26
# 29158                 40.634250            43.727774    -3.333333e+26
# 35570                 33.943626         13798.000000    -3.333333e+26
# 38622                 28.541848             9.930809    -3.333333e+26
# 60009                 39.089475            54.219664    -3.333333e+26
# 75251                 29.878716            61.525140    -3.333333e+26
# 82918                 37.718591           355.143396    -3.333333e+26
# 83255                 28.442867           167.043910    -3.333333e+26
#
#       Credit_Score
# 5545      Standard
# 26177         Good
# 29158     Standard
# 35570     Standard
# 38622     Standard
# 60009     Standard
# 75251     Standard
# 82918     Standard
# 83255         Poor

# %%
df.loc[df["Monthly_Balance"]<Lower_fence,"Monthly_Balance"]=0

# %%
df[df["Monthly_Balance"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df["Credit_Score"].describe()
# Out:
# count        91893
# unique           3
# top       Standard
# freq         48875
# Name: Credit_Score, dtype: object

# %%
df.isna().sum()
# Out:
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Delay_from_due_date            0
# Num_of_Delayed_Payment         0
# Changed_Credit_Limit        1940
# Num_Credit_Inquiries        1809
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Total_EMI_per_month            0
# Monthly_Balance                0
# Credit_Score                   0
# dtype: int64

# %%
df["Changed_Credit_Limit"]
# Out:
# 0        11.27
# 2          NaN
# 3         6.27
# 5         9.27
# 6        11.27
#          ...
# 99994      9.5
# 99995     11.5
# 99996     11.5
# 99997     11.5
# 99999     11.5
# Name: Changed_Credit_Limit, Length: 91893, dtype: object

# %%
df["Changed_Credit_Limit"]=df["Changed_Credit_Limit"].replace("_",np.nan)

# %%
df["Changed_Credit_Limit"]=df["Changed_Credit_Limit"].ffill()

# %%
df["Changed_Credit_Limit"].isna().sum()
# Out:
# np.int64(0)

# %%
def removal(text):
    return re.sub("_","",text)

# %%
df["Num_of_Delayed_Payment"]=df["Num_of_Delayed_Payment"].apply(lambda x: removal(x))

# %%
df["Num_of_Delayed_Payment"]=df["Num_of_Delayed_Payment"].astype("int")

# %%
df.isna().sum()
# Out:
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Delay_from_due_date            0
# Num_of_Delayed_Payment         0
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1809
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Total_EMI_per_month            0
# Monthly_Balance                0
# Credit_Score                   0
# dtype: int64

# %%
df["Num_Credit_Inquiries"]
# Out:
# 0        4.0
# 2        4.0
# 3        4.0
# 5        4.0
# 6        4.0
#         ...
# 99994    3.0
# 99995    3.0
# 99996    3.0
# 99997    3.0
# 99999    3.0
# Name: Num_Credit_Inquiries, Length: 91893, dtype: float64

# %%
mean= df["Num_Credit_Inquiries"].fillna(df["Num_Credit_Inquiries"].mean())
median= df["Num_Credit_Inquiries"].fillna(df["Num_Credit_Inquiries"].median())
std= df["Num_Credit_Inquiries"].fillna(df["Monthly_Inhand_Salary"].std())
ffill= df["Num_Credit_Inquiries"].ffill()
bfill= df["Num_Credit_Inquiries"].bfill()
const= df["Num_Credit_Inquiries"].fillna(0)

# %%
print("the mean is=",mean.mean())
print("the median is=",median.mean())
print("the std is=",std.mean())
print("the ffill is=",ffill.mean())
print("the bfill is=",bfill.mean())
print("the const is=",const.mean())
# Out:
# the mean is= 27.51933750721549
# the median is= 27.09570913997802
# the std is= 89.36767008660773
# the ffill is= 27.494640505805666
# the bfill is= 27.511562360571535
# the const is= 26.97759350549008

# %%
ffill.std()
# Out:
# np.float64(191.91541772543533)

# %%
bfill.std()
# Out:
# np.float64(192.06133704188477)

# %%
df["Num_Credit_Inquiries"].std()
# Out:
# np.float64(192.06123356213357)

# %%
df["Num_Credit_Inquiries"]=df["Num_Credit_Inquiries"].ffill()

# %%
mini=df["Num_Credit_Inquiries"].min()
Q1=df["Num_Credit_Inquiries"].quantile(0.25)
Q2=df["Num_Credit_Inquiries"].quantile(0.50)
Q3=df["Num_Credit_Inquiries"].quantile(0.75)
Max=df["Num_Credit_Inquiries"].max()

IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 18.0
# Lower- -6.0

# %%
df[df["Num_Credit_Inquiries"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df["Num_Credit_Inquiries"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Credit_Mix"]
# Out:
# 0         Bad
# 2        Good
# 3        Good
# 5        Good
# 6        Good
#          ...
# 99994     Bad
# 99995     Bad
# 99996     Bad
# 99997    Good
# 99999    Good
# Name: Credit_Mix, Length: 91893, dtype: object

# %%
df["Outstanding_Debt"].astype("float")
# Out:
# 0        809.98
# 2        809.98
# 3        809.98
# 5        809.98
# 6        809.98
#           ...
# 99994    502.38
# 99995    502.38
# 99996    502.38
# 99997    502.38
# 99999    502.38
# Name: Outstanding_Debt, Length: 91893, dtype: float64

# %%
df["Credit_Utilization_Ratio"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# _______          6483
# Lawyer           6051
# Engineer         5868
# Architect        5825
# Mechanic         5784
# Scientist        5758
# Teacher          5747
# Developer        5736
# Accountant       5726
# Media_Manager    5704
# Entrepreneur     5680
# Journalist       5595
# Doctor           5587
# Manager          5492
# Musician         5457
# Writer           5400
# Name: count, dtype: int64

# %%
df["Occupation"]=df["Occupation"].replace("_______",'Others')

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Others           6483
# Lawyer           6051
# Engineer         5868
# Architect        5825
# Mechanic         5784
# Scientist        5758
# Teacher          5747
# Developer        5736
# Accountant       5726
# Media_Manager    5704
# Entrepreneur     5680
# Journalist       5595
# Doctor           5587
# Manager          5492
# Musician         5457
# Writer           5400
# Name: count, dtype: int64

# %%
df["Monthly_Balance"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Credit_Score"].describe()
# Out:
# count        91893
# unique           3
# top       Standard
# freq         48875
# Name: Credit_Score, dtype: object

# %%
df.isna().sum()
# Out:
# Month                       0
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Total_EMI_per_month         0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
df
# Out:
#          Month  Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      January   23  Scientist       19114.12            1824.843333
# 2        March    0  Scientist       19114.12            1824.843333
# 3        April   23  Scientist       19114.12            1824.843333
# 5         June   23  Scientist       19114.12            1824.843333
# 6         July   23  Scientist       19114.12            1824.843333
# ...        ...  ...        ...            ...                    ...
# 99994    March   25   Mechanic       39628.99            3359.415833
# 99995    April   25   Mechanic       39628.99            3359.415833
# 99996      May   25   Mechanic       39628.99            3359.415833
# 99997     June   25   Mechanic       39628.99            3359.415833
# 99999   August   25   Mechanic       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                      3                4              3            4
# 2                      3                4              3            4
# 3                      3                4              3            4
# 5                      3                4              3            4
# 6                      3                4              3            4
# ...                  ...              ...            ...          ...
# 99994                  4                6              7            2
# 99995                  4                6              7            2
# 99996                  4                6              7            2
# 99997                  4                6           5729            2
# 99999                  4                6              7            2
#
#        Delay_from_due_date  Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                        3                       7                11.27
# 2                        3                       7                11.27
# 3                        5                       4                 6.27
# 5                        8                       4                 9.27
# 6                        3                       8                11.27
# ...                    ...                     ...                  ...
# 99994                   20                       6                  9.5
# 99995                   23                       7                 11.5
# 99996                   18                       7                 11.5
# 99997                   27                       6                 11.5
# 99999                   18                       6                 11.5
#
#        Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 0                       4.0        Bad            809.98
# 2                       4.0       Good            809.98
# 3                       4.0       Good            809.98
# 5                       4.0       Good            809.98
# 6                       4.0       Good            809.98
# ...                     ...        ...               ...
# 99994                   3.0        Bad            502.38
# 99995                   3.0        Bad            502.38
# 99996                   3.0        Bad            502.38
# 99997                   3.0       Good            502.38
# 99999                   3.0       Good            502.38
#
#        Credit_Utilization_Ratio  Total_EMI_per_month  Monthly_Balance  \
# 0                     26.822620            49.574949       312.494089
# 2                     28.609352            49.574949       331.209863
# 3                     31.377862            49.574949       223.451310
# 5                     27.262259            49.574949       340.479212
# 6                     22.537593            49.574949       244.565317
# ...                         ...                  ...              ...
# 99994                 39.323569            35.104023       410.256158
# 99995                 34.663572            35.104023       479.866228
# 99996                 40.565631            35.104023       496.651610
# 99997                 41.255522            35.104023       516.809083
# 99999                 34.192463            35.104023       393.673696
#
#       Credit_Score
# 0             Good
# 2             Good
# 3             Good
# 5             Good
# 6             Good
# ...            ...
# 99994         Poor
# 99995         Poor
# 99996         Poor
# 99997         Poor
# 99999         Poor
#
# [91893 rows x 19 columns]

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt

# %%
df["Num_of_Delayed_Payment"]=df["Num_of_Delayed_Payment"].astype("int")

# %%
df.isna().any().sum()
# Out:
# np.int64(0)

# %%
df["Interest_Rate"].value_counts()
# Out:
# Interest_Rate
# 8       4617
# 5       4553
# 6       4353
# 10      4187
# 7       4175
#         ...
# 4104       1
# 219        1
# 3085       1
# 159        1
# 3177       1
# Name: count, Length: 1641, dtype: int64

# %%
mini=df["Interest_Rate"].min()
Q1=df["Interest_Rate"].quantile(0.25)
Q2=df["Interest_Rate"].quantile(0.50)
Q3=df["Interest_Rate"].quantile(0.75)
Max=df["Interest_Rate"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 38.0
# Lower- -10.0

# %%
df[df["Interest_Rate"]>Upper_fence]
# Out:
#           Month  Age     Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 44          May   31         Lawyer       73928.46            5988.705000
# 89     February   33       Engineer       88640.24            7266.686667
# 167      August   41       Musician       19514.88            1074.584583
# 178       March   20   Entrepreneur      106733.13            8873.427500
# 229        June   40      Architect       28572.39            2210.032500
# ...         ...  ...            ...            ...                    ...
# 99791    August   54       Musician       99520.50            8479.375000
# 99801  February   16      Developer       14937.49            1142.790833
# 99882     March   31       Mechanic    16884797.00            5440.945000
# 99914     March   54  Media_Manager       20059.98            1523.665000
# 99997      June   25       Mechanic       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 44                     4                5           5318            0
# 89                     3                6            433            2
# 167                    7                5           5240            0
# 178                    4                4           4975            0
# 229                    6                3            668            3
# ...                  ...              ...            ...          ...
# 99791                  3                1           4396            3
# 99801                  8                8            387         -100
# 99882                  7                3           1947            0
# 99914                  8                5            360            4
# 99997                  4                6           5729            2
#
#        Delay_from_due_date  Num_of_Delayed_Payment Changed_Credit_Limit  \
# 44                      11                       7                10.14
# 89                       4                       2                 3.51
# 167                     26                      11                 4.17
# 178                      2                       6                 0.86
# 229                     25                      11                 4.89
# ...                    ...                     ...                  ...
# 99791                    8                       5                 4.08
# 99801                   42                      13                21.17
# 99882                    7                       8                12.57
# 99914                   25                       9                 2.97
# 99997                   27                       6                 11.5
#
#        Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 44                      2.0        Bad            548.20
# 89                      3.0       Good            950.36
# 167                     4.0        Bad            881.40
# 178                     0.0       Good             76.23
# 229                     2.0   Standard            400.07
# ...                     ...        ...               ...
# 99791                   5.0       Good            547.21
# 99801                   6.0        Bad           3699.44
# 99882                   2.0   Standard            330.60
# 99914                   3.0       Good            909.01
# 99997                   3.0       Good            502.38
#
#        Credit_Utilization_Ratio  Total_EMI_per_month  Monthly_Balance  \
# 44                    26.333310             0.000000       690.918664
# 89                    41.036168           135.173371       674.320507
# 167                   28.781888             0.000000       343.682459
# 178                   42.070459             0.000000       955.309921
# 229                   35.693949            69.602920       312.135495
# ...                         ...                  ...              ...
# 99791                 38.798114           196.528591       743.845393
# 99801                 35.964828            50.960878       203.430341
# 99882                 38.524095             0.000000       536.342920
# 99914                 29.204711            45.076827       265.722534
# 99997                 41.255522            35.104023       516.809083
#
#       Credit_Score
# 44            Good
# 89            Good
# 167           Poor
# 178           Good
# 229       Standard
# ...            ...
# 99791         Good
# 99801     Standard
# 99882     Standard
# 99914         Poor
# 99997         Poor
#
# [1891 rows x 19 columns]

# %%
df.loc[df["Interest_Rate"]>Upper_fence,"Interest_Rate"]=9

# %%
df[df["Interest_Rate"]>Upper_fence]
# Out:
# Empty DataFrame
# Columns: [Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Total_EMI_per_month, Monthly_Balance, Credit_Score]
# Index: []

# %%
df
# Out:
#          Month  Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      January   23  Scientist       19114.12            1824.843333
# 2        March    0  Scientist       19114.12            1824.843333
# 3        April   23  Scientist       19114.12            1824.843333
# 5         June   23  Scientist       19114.12            1824.843333
# 6         July   23  Scientist       19114.12            1824.843333
# ...        ...  ...        ...            ...                    ...
# 99994    March   25   Mechanic       39628.99            3359.415833
# 99995    April   25   Mechanic       39628.99            3359.415833
# 99996      May   25   Mechanic       39628.99            3359.415833
# 99997     June   25   Mechanic       39628.99            3359.415833
# 99999   August   25   Mechanic       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                      3                4              3            4
# 2                      3                4              3            4
# 3                      3                4              3            4
# 5                      3                4              3            4
# 6                      3                4              3            4
# ...                  ...              ...            ...          ...
# 99994                  4                6              7            2
# 99995                  4                6              7            2
# 99996                  4                6              7            2
# 99997                  4                6              9            2
# 99999                  4                6              7            2
#
#        Delay_from_due_date  Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                        3                       7                11.27
# 2                        3                       7                11.27
# 3                        5                       4                 6.27
# 5                        8                       4                 9.27
# 6                        3                       8                11.27
# ...                    ...                     ...                  ...
# 99994                   20                       6                  9.5
# 99995                   23                       7                 11.5
# 99996                   18                       7                 11.5
# 99997                   27                       6                 11.5
# 99999                   18                       6                 11.5
#
#        Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 0                       4.0        Bad            809.98
# 2                       4.0       Good            809.98
# 3                       4.0       Good            809.98
# 5                       4.0       Good            809.98
# 6                       4.0       Good            809.98
# ...                     ...        ...               ...
# 99994                   3.0        Bad            502.38
# 99995                   3.0        Bad            502.38
# 99996                   3.0        Bad            502.38
# 99997                   3.0       Good            502.38
# 99999                   3.0       Good            502.38
#
#        Credit_Utilization_Ratio  Total_EMI_per_month  Monthly_Balance  \
# 0                     26.822620            49.574949       312.494089
# 2                     28.609352            49.574949       331.209863
# 3                     31.377862            49.574949       223.451310
# 5                     27.262259            49.574949       340.479212
# 6                     22.537593            49.574949       244.565317
# ...                         ...                  ...              ...
# 99994                 39.323569            35.104023       410.256158
# 99995                 34.663572            35.104023       479.866228
# 99996                 40.565631            35.104023       496.651610
# 99997                 41.255522            35.104023       516.809083
# 99999                 34.192463            35.104023       393.673696
#
#       Credit_Score
# 0             Good
# 2             Good
# 3             Good
# 5             Good
# 6             Good
# ...            ...
# 99994         Poor
# 99995         Poor
# 99996         Poor
# 99997         Poor
# 99999         Poor
#
# [91893 rows x 19 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal=OrdinalEncoder()

# %%
os=ordinal.fit_transform(df[["Month"]])
n=ordinal.fit_transform(df[["Occupation"]])
o=ordinal.fit_transform(df[["Credit_Mix"]])

# %%
df["Month"]=os

df["Occupation"]=n
df["Credit_Mix"]=o

# %%
df
# Out:
#        Month  Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0        3.0   23        13.0       19114.12            1824.843333
# 2        6.0    0        13.0       19114.12            1824.843333
# 3        0.0   23        13.0       19114.12            1824.843333
# 5        5.0   23        13.0       19114.12            1824.843333
# 6        4.0   23        13.0       19114.12            1824.843333
# ...      ...  ...         ...            ...                    ...
# 99994    6.0   25         9.0       39628.99            3359.415833
# 99995    0.0   25         9.0       39628.99            3359.415833
# 99996    7.0   25         9.0       39628.99            3359.415833
# 99997    5.0   25         9.0       39628.99            3359.415833
# 99999    1.0   25         9.0       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                      3                4              3            4
# 2                      3                4              3            4
# 3                      3                4              3            4
# 5                      3                4              3            4
# 6                      3                4              3            4
# ...                  ...              ...            ...          ...
# 99994                  4                6              7            2
# 99995                  4                6              7            2
# 99996                  4                6              7            2
# 99997                  4                6              9            2
# 99999                  4                6              7            2
#
#        Delay_from_due_date  Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                        3                       7                11.27
# 2                        3                       7                11.27
# 3                        5                       4                 6.27
# 5                        8                       4                 9.27
# 6                        3                       8                11.27
# ...                    ...                     ...                  ...
# 99994                   20                       6                  9.5
# 99995                   23                       7                 11.5
# 99996                   18                       7                 11.5
# 99997                   27                       6                 11.5
# 99999                   18                       6                 11.5
#
#        Num_Credit_Inquiries  Credit_Mix  Outstanding_Debt  \
# 0                       4.0         0.0            809.98
# 2                       4.0         1.0            809.98
# 3                       4.0         1.0            809.98
# 5                       4.0         1.0            809.98
# 6                       4.0         1.0            809.98
# ...                     ...         ...               ...
# 99994                   3.0         0.0            502.38
# 99995                   3.0         0.0            502.38
# 99996                   3.0         0.0            502.38
# 99997                   3.0         1.0            502.38
# 99999                   3.0         1.0            502.38
#
#        Credit_Utilization_Ratio  Total_EMI_per_month  Monthly_Balance  \
# 0                     26.822620            49.574949       312.494089
# 2                     28.609352            49.574949       331.209863
# 3                     31.377862            49.574949       223.451310
# 5                     27.262259            49.574949       340.479212
# 6                     22.537593            49.574949       244.565317
# ...                         ...                  ...              ...
# 99994                 39.323569            35.104023       410.256158
# 99995                 34.663572            35.104023       479.866228
# 99996                 40.565631            35.104023       496.651610
# 99997                 41.255522            35.104023       516.809083
# 99999                 34.192463            35.104023       393.673696
#
#       Credit_Score
# 0             Good
# 2             Good
# 3             Good
# 5             Good
# 6             Good
# ...            ...
# 99994         Poor
# 99995         Poor
# 99996         Poor
# 99997         Poor
# 99999         Poor
#
# [91893 rows x 19 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la=LabelEncoder()

# %%
label=la.fit_transform(df[["Credit_Score"]])

# %%
df["Credit_Score"]=label

# %%
x=df.drop("Credit_Score",axis=1)
y=df["Credit_Score"]

# %%
x=df.drop("Credit_Score",axis=1)
y=df["Credit_Score"]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn= MinMaxScaler()

# %%
x= mn.fit_transform(x)

# %%
x
# Out:
# array([[4.28571429e-01, 2.64428604e-03, 8.66666667e-01, ...,
#         2.04039308e-01, 6.02141954e-04, 1.95060041e-01],
#        [8.57142857e-01, 0.00000000e+00, 8.66666667e-01, ...,
#         2.65399510e-01, 6.02141954e-04, 2.06742501e-01],
#        [0.00000000e+00, 2.64428604e-03, 8.66666667e-01, ...,
#         3.60476045e-01, 6.02141954e-04, 1.39479187e-01],
#        ...,
#        [1.00000000e+00, 2.87422396e-03, 6.00000000e-01, ...,
#         6.76003639e-01, 4.26376731e-04, 3.10011891e-01],
#        [7.14285714e-01, 2.87422396e-03, 6.00000000e-01, ...,
#         6.99695978e-01, 4.26376731e-04, 3.22594265e-01],
#        [1.42857143e-01, 2.87422396e-03, 6.00000000e-01, ...,
#         4.57135441e-01, 4.26376731e-04, 2.45732671e-01]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=104,shuffle=True,stratify=y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
l=LogisticRegression()

# %%
l.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
l.score(x_train,y_train)
# Out:
# 0.6149985036863727

# %%
l.score(x_test,y_test)
# Out:
# 0.617770281299309

# %%
l_prob= l.predict_proba(x_test)[:,1]

# %%
result=pd.DataFrame(l_prob,columns=["Logic_prob"])

# %%
result
# Out:
#        Logic_prob
# 0        0.268687
# 1        0.390239
# 2        0.525952
# 3        0.171986
# 4        0.227962
# ...           ...
# 18374    0.147365
# 18375    0.741694
# 18376    0.065396
# 18377    0.146511
# 18378    0.339209
#
# [18379 rows x 1 columns]

# %% [markdown]
# # Conclusion

# %%
#Based on the initial inspection of the dataset, the following general conclusions can be drawn:

# %% [markdown]
# # 1. Income and Salary:

# %%
#Higher annual income and monthly in-hand salary seem to correlate with better credit scores.

# %% [markdown]
# # 2.Financial Management:

# %%
#Individuals with fewer delayed payments, lower credit utilization ratios, and fewer credit inquiries tend to have better credit scores.

# %% [markdown]
# # 3.Credit Utilization:

# %%
# Maintaining a lower credit utilization ratio is crucial for a better credit score

# %% [markdown]
# # 4.Credit Mix

# %%
# Having a balanced mix of credit (e.g., loans, credit cards) appears to be beneficial.

# %% [markdown]
# # Recommendations

# %% [markdown]
# # 1.Financial Education:

# %%
#1Provide education on managing credit utilization and avoiding delayed payments.
#2Emphasize the importance of maintaining a diverse credit mix and keeping the number of credit inquiries low.

# %% [markdown]
# # 2.Personalized Advice:

# %%
#Use predictive models to offer personalized financial advice based onindividual financial behaviors and characteristics.

# %% [markdown]
# # 3.Policy Development:

# %%
#Financial institutions can develop policies and products that incentivize good financial behavior, such as lower interest rates for individuals with a
#history of timely payments and low credit utilization.
